# %%
# !python3 /kaggle/input/bundle/generate_dataset.py
# Out:
# Found sheets: ['orders', 'inventory']
# → Using Orders sheet:   'orders'
# → Using Inventory sheet:'inventory'
#
# 📊 ORDERS DATA QUALITY SUMMARY:
#    Total records: 165,319
#    Date range: 2024-05-21 09:41:56.330000 to 2025-05-21 09:32:37.943000
#    Unique orders: 81,775
#    Unique SKUs: 67,907
#    Records with discounts: 118,349
# ✅ Saved transformed orders → orders_data.csv (165,319×23)
#    Quantity range: 0 to 167
#
# 📦 INVENTORY DATA QUALITY SUMMARY:
#    Total SKUs: 6,825
#    SKUs in stock: 6,049
#    SKUs out of stock: 776
#    Total inventory units: 23,032
#    Stock level distribution:
#      Critical_Low: 5,623
#      Out_of_Stock: 776
#      Low: 417
#      Medium: 9
#
# ⚠️  WARNING: 61082 SKUs in orders but not in inventory:
#    Examples: ['9-5277002118|EB5690|5A', '9-3367010721|EE0018|9-12', '2-8738011201', '3RE2643|LP40|TU', '9-4768000763|EE0019|32']
# ✅ Saved transformed inventory → inventory_data.csv (6,825×4)
#
# 🎯 DATA PREPROCESSING COMPLETE!
#    Files ready for bundling analysis:
#    • orders_data.csv
#    • inventory_data.csv

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<3.0,>=1.25.0->faiss-cpu) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<3.0,>=1.25.0->faiss-cpu) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<3.0,>=1.25.0->faiss-cpu) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<3.0,>=1.25.0->faiss-cpu) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<3.0,>=1.25.0->faiss-cpu) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<3.0,>=1.25.0->faiss-cpu) (2024.2.0)
# Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl (31.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 55.8 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.11.0

# %%
import pandas as pd
import numpy as np
# SentenceTransformer is imported here because the pre-computation utility is now in this file
# It will ONLY be used if the embedding files need to be created for the first time.
from sentence_transformers import SentenceTransformer
import faiss # Using FAISS as requested
import warnings
import os
from itertools import combinations # For generating 3-item bundle combinations
import random # For picking users

warnings.filterwarnings('ignore')

# Define Kaggle paths globally
KAGGLE_WORKING_DIR = "/kaggle/working/"
EMBEDDINGS_PATH = os.path.join(KAGGLE_WORKING_DIR, 'product_embeddings.npy')
SKUS_JSON_PATH = os.path.join(KAGGLE_WORKING_DIR, 'product_skus.json')

# Input file paths
ORDERS_FILE_PATH = '/kaggle/working/orders_data.csv'
INVENTORY_FILE_PATH = '/kaggle/working/inventory_data.csv'
SUGGESTIONS_FILE_PATH = '/kaggle/input/bundle/final_dataset_with_suggestions2.csv'


HIGH_MARGIN_CATEGORIES = {"Προϊόντα Ομορφιάς", "BEAUTY"}

# --- 0. UTILITY FUNCTION FOR ONE-TIME EMBEDDING PRE-COMPUTATION ---
def create_and_save_embeddings_utility(
    orders_filepath=ORDERS_FILE_PATH,
    output_embeddings_path=EMBEDDINGS_PATH,
    output_skus_path=SKUS_JSON_PATH
    ):
    print("🚀 Starting one-time embedding generation for FAISS...")
    try:
        df_orders = pd.read_csv(orders_filepath)
    except FileNotFoundError:
        print(f"❌ Error: The file '{orders_filepath}' was not found for pre-computation.")
        return False
    products_to_embed = df_orders[['SKU', 'Item title']].drop_duplicates(subset=['SKU']).set_index('SKU')
    if products_to_embed.empty:
        print(f"❌ No products found in '{orders_filepath}' to embed.")
        return False
    print(f"  > Loading SentenceTransformer model (all-MiniLM-L6-v2) for pre-computation...")
    model = SentenceTransformer('all-MiniLM-L6-v2')
    print(f"  > Encoding {len(products_to_embed)} product titles...")
    titles = products_to_embed['Item title'].fillna('').tolist()
    embeddings_array = model.encode(titles, show_progress_bar=True)
    os.makedirs(KAGGLE_WORKING_DIR, exist_ok=True)
    np.save(output_embeddings_path, embeddings_array)
    products_to_embed.index.to_series().to_json(output_skus_path, orient='values')
    print(f"✔ Embeddings saved to '{output_embeddings_path}' & SKU list to '{output_skus_path}'")
    return True

# --- UTILITY FUNCTIONS (for vector math & Jaccard) ---
def cosine_similarity_numpy(vec1, vec2):
    if vec1 is None or vec2 is None: return 0.0
    vec1, vec2 = np.asarray(vec1, dtype=np.float32), np.asarray(vec2, dtype=np.float32)
    norm_vec1, norm_vec2 = np.linalg.norm(vec1), np.linalg.norm(vec2)
    if norm_vec1 == 0 or norm_vec2 == 0 : return 0.0
    return np.dot(vec1, vec2) / (norm_vec1 * norm_vec2)

def jaccard_similarity_sets(set1, set2):
    if not all(isinstance(s, set) for s in [set1, set2]): return 0.0
    if not set1 or not set2: return 0.0
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    return intersection / union if union > 0 else 0.0

# --- 1. SETUP: LOAD ALL DATA & PRE-COMPUTED EMBEDDINGS ---
def load_and_engineer_data(
    orders_filepath, inventory_filepath, suggestions_filepath,
    embeddings_filepath, skus_json_filepath):
    print("🚀 Loading all data and pre-computed embeddings...")
    try:
        orders_df = pd.read_csv(orders_filepath, parse_dates=['CreatedDate'])
        inventory_df = pd.read_csv(inventory_filepath)
        suggestions_df = pd.read_csv(suggestions_filepath)
        precomputed_embeddings_array = np.load(embeddings_filepath)
        precomputed_skus = pd.read_json(skus_json_filepath, typ='series')
    except FileNotFoundError as e: # Error printed in main
        print(f"Initial data loading error: {e}")
        return None, None 
    print("  > Engineering master product DataFrame...")
    products = orders_df.groupby('SKU').agg(ItemTitle=('Item title', 'first'),Category=('Category', 'first'),AvgUnitPrice=('FinalUnitPrice', 'mean')).reset_index().set_index('SKU')
    if products.index.dtype == 'object' and 'SKU' in suggestions_df.columns: 
        suggestions_df['SKU'] = suggestions_df['SKU'].astype(str)
    
    if 'SKU' in suggestions_df.columns and suggestions_df.index.name != 'SKU':
        suggestions_df_indexed = suggestions_df.drop_duplicates(subset=['SKU']).set_index('SKU')
    elif 'SKU' in suggestions_df.columns: 
         suggestions_df_indexed = suggestions_df.drop_duplicates(subset=['SKU']).set_index('SKU')
    else: 
        print("Warning: 'SKU' column not found in suggestions_df. Cannot merge 'similar_items'.")
        suggestions_df_indexed = pd.DataFrame(index=products.index) 
        suggestions_df_indexed['similar_items'] = np.nan

    products = pd.merge(products, suggestions_df_indexed[['similar_items']], on='SKU', how='left')
    
    embedding_map = pd.Series(list(precomputed_embeddings_array), index=precomputed_skus)
    products['NameEmbedding'] = products.index.map(embedding_map)
    if products['NameEmbedding'].isnull().all(): # Error printed in main
        print("Critical error: No embeddings mapped.")
        return None, None 
    print(f"    Successfully mapped {products['NameEmbedding'].notna().sum()} pre-computed embeddings.")
    print("  > Calculating stock scores...")
    max_date = orders_df['CreatedDate'].max()
    recent_date_threshold = max_date - pd.Timedelta(days=90) if pd.notna(max_date) else pd.Timestamp.min
    recent_sales = orders_df[orders_df['CreatedDate'] >= recent_date_threshold]
    sales_velocity_df = recent_sales.groupby('SKU')['Quantity'].sum().reset_index()
    sales_velocity_df['SalesVelocity'] = sales_velocity_df['Quantity'] / 90
    products = pd.merge(products, sales_velocity_df[['SKU', 'SalesVelocity']].set_index('SKU'), on='SKU', how='left')
    products = pd.merge(products, inventory_df[['SKU', 'Quantity']].set_index('SKU'), on='SKU', how='left')
    products.fillna({'SalesVelocity': 0, 'Quantity': 0}, inplace=True)
    products['StockToSalesRatio'] = products['Quantity'] / (products['SalesVelocity'] + 1e-6)
    products['StockLevelScore'] = products['StockToSalesRatio'].rank(pct=True).fillna(0)
    print("  > Engineering purchase vectors...")
    user_item_interactions = orders_df.groupby('SKU')['UserID'].apply(set).to_dict()
    products['PurchaseVector'] = pd.Series(products.index.map(user_item_interactions), index=products.index).apply(lambda v: v if isinstance(v, set) else set())
    print("✔ Master product features complete.")
    print("🚀 Creating user profile vectors...")
    user_profiles = {}
    sku_to_embedding = products['NameEmbedding'].dropna().to_dict()
    user_item_groups = orders_df.dropna(subset=['UserID', 'SKU', 'FinalUnitPrice']).groupby('UserID')
    for user_id, group in user_item_groups:
        item_embeddings = [sku_to_embedding.get(sku) for sku in group['SKU'] if sku in sku_to_embedding and sku_to_embedding.get(sku) is not None]
        profile_vec = np.mean([emb for emb in item_embeddings if emb is not None], axis=0) if any(emb is not None for emb in item_embeddings) else None
        user_profiles[user_id] = {'profile_vector': profile_vec, 'avg_price': group['FinalUnitPrice'].mean() if not group['FinalUnitPrice'].empty else 0}
    print(f"✔ Created {len(user_profiles)} user profiles.")
    return products, user_profiles

def build_faiss_index_from_loaded_embeddings(products_df_with_embeddings):
    print("🚀 Building FAISS index from loaded embeddings...")
    embeddings_series = products_df_with_embeddings['NameEmbedding'].dropna()
    if embeddings_series.empty: return None, None
    faiss_embeddings_array = np.array(embeddings_series.tolist()).astype('float32')
    faiss_skus_in_index = embeddings_series.index.tolist()
    if faiss_embeddings_array.ndim != 2 or faiss_embeddings_array.shape[0] == 0: return None, None
    d = faiss_embeddings_array.shape[1]
    faiss.normalize_L2(faiss_embeddings_array) 
    index = faiss.IndexFlatL2(d)
    index.add(faiss_embeddings_array)
    print(f"✔ FAISS index built with {index.ntotal} items.")
    return index, faiss_skus_in_index

# --- 2. REFACTOR: CALCULATE SCORE FOR A SINGLE CANDIDATE ITEM ---
def calculate_single_candidate_score(
    candidate_sku: str, target_sku_for_context: str, products_df: pd.DataFrame,
    weights: dict, user_id: str, user_profiles: dict
    ):
    if candidate_sku not in products_df.index or target_sku_for_context not in products_df.index:
        return 0.0 

    cand_item = products_df.loc[candidate_sku]
    target_item = products_df.loc[target_sku_for_context]
    user_profile = user_profiles.get(user_id, {})
    user_profile_vector = user_profile.get('profile_vector')
    user_avg_price = user_profile.get('avg_price', 0)

    purchase_sim = jaccard_similarity_sets(target_item.get('PurchaseVector'), cand_item.get('PurchaseVector'))
    price_context_sim = np.exp(-10 * (abs(target_item.AvgUnitPrice - cand_item.AvgUnitPrice) / (target_item.AvgUnitPrice + 1e-6)))
    name_sim = cosine_similarity_numpy(target_item.NameEmbedding, cand_item.NameEmbedding)
    category_sim = 1.0 if target_item.Category == cand_item.Category else 0.0
    user_taste_sim = cosine_similarity_numpy(cand_item.NameEmbedding, user_profile_vector)
    price_affinity_sim = np.exp(-5 * (abs(cand_item.AvgUnitPrice - user_avg_price) / (user_avg_price + 1e-6))) if user_avg_price > 0 else 0.0
    stock_level_score = cand_item.StockLevelScore
    
    total_score = (
        (purchase_sim * weights.get('purchase', 0)) + 
        (price_context_sim * weights.get('price_context', 0)) + 
        (name_sim * weights.get('name', 0)) + 
        (category_sim * weights.get('category', 0)) + 
        (user_taste_sim * weights.get('user_taste', 0)) + 
        (price_affinity_sim * weights.get('price_affinity', 0)) + 
        (stock_level_score * weights.get('stock_level', 0))
    )
    total_active_weight = sum(v for k,v in weights.items() if k in ['purchase','price_context','name','category','user_taste','price_affinity','stock_level'] and v > 0)
    return total_score / total_active_weight if total_active_weight > 0 else 0.0

# --- 3. NEW MAIN FUNCTION FOR SMART BUNDLING ---
def suggest_smart_bundle_for_user(
    target_item_name: str, user_id: str, products_df: pd.DataFrame,
    user_profiles: dict, weights: dict,
    bundle_score_bonus_3_item: float = 1.1, 
    min_quality_threshold: float = 0.3, 
    prefer_3_item_score_ratio: float = 1.0 
    ):
    # This function's internal print statements can be verbose for 1000 examples,
    # so they are commented out here but can be re-enabled for debugging individual calls.
    # print(f"\n--- Suggesting Smart Bundle for '{target_item_name}' for user '{user_id}' ---") 
    
    target_items_query = products_df[products_df['ItemTitle'].str.lower() == target_item_name.lower()]
    if target_items_query.empty: return {"error": f"Item '{target_item_name}' not found."}
    target_item_row = target_items_query.iloc[0]
    target_sku = target_item_row.name
    
    similar_items_str = target_item_row.get('similar_items', '')
    if pd.isna(similar_items_str) or not similar_items_str:
        return {"error": f"Item '{target_item_name}' has no pre-defined 'similar_items' to create bundles from."}
    
    candidate_names = [name.strip() for name in similar_items_str.split('|')]
    candidate_skus_from_names_df = products_df[products_df['ItemTitle'].isin(candidate_names)]
    alternative_skus = sorted(list(set(sku for sku in candidate_skus_from_names_df.index.tolist() if sku != target_sku)))

    if not alternative_skus:
        return {"error": "No valid alternative items (excluding the target itself) found from 'similar_items' list to create bundles."}

    # print(f"  > Considering {len(alternative_skus)} unique alternatives for bundling with '{target_item_name}' (SKU: {target_sku}): {alternative_skus}")

    best_2_item_bundle_details = None
    max_2_item_score = -1.0
    
    for alt_sku in alternative_skus:
        score = calculate_single_candidate_score(alt_sku, target_sku, products_df, weights, user_id, user_profiles)
        if score > max_2_item_score:
            max_2_item_score = score
            best_2_item_bundle_details = {'skus': tuple(sorted((target_sku, alt_sku))), 'score': score}
    
    best_3_item_bundle_details = None
    max_3_item_score = -1.0

    if len(alternative_skus) >= 2:
        for alt_sku_A, alt_sku_B in combinations(alternative_skus, 2):
            score_A = calculate_single_candidate_score(alt_sku_A, target_sku, products_df, weights, user_id, user_profiles)
            score_B = calculate_single_candidate_score(alt_sku_B, target_sku, products_df, weights, user_id, user_profiles)
            current_3_item_score = ((score_A + score_B) / 2) * bundle_score_bonus_3_item 
            if current_3_item_score > max_3_item_score:
                max_3_item_score = current_3_item_score
                best_3_item_bundle_details = {'skus': tuple(sorted((target_sku, alt_sku_A, alt_sku_B))), 'score': current_3_item_score}
                
    chosen_bundle_skus = None
    chosen_bundle_type = ""
    final_bundle_score = -1.0

    # print(f"  > Best 2-item bundle (Target + Alt) score: {max_2_item_score:.3f} (Bundle SKUs: {best_2_item_bundle_details['skus'] if best_2_item_bundle_details else 'N/A'})")
    # print(f"  > Best 3-item bundle (Target + Alt1 + Alt2) score: {max_3_item_score:.3f} (Bundle SKUs: {best_3_item_bundle_details['skus'] if best_3_item_bundle_details else 'N/A'})")
    
    three_item_viable = best_3_item_bundle_details and best_3_item_bundle_details['score'] >= min_quality_threshold
    two_item_viable = best_2_item_bundle_details and best_2_item_bundle_details['score'] >= min_quality_threshold

    if three_item_viable and two_item_viable:
        if best_3_item_bundle_details['score'] >= best_2_item_bundle_details['score'] * prefer_3_item_score_ratio:
            chosen_bundle_skus = best_3_item_bundle_details['skus']
            chosen_bundle_type = "3-Item Bundle"
            final_bundle_score = best_3_item_bundle_details['score']
        else:
            chosen_bundle_skus = best_2_item_bundle_details['skus']
            chosen_bundle_type = "2-Item Bundle"
            final_bundle_score = best_2_item_bundle_details['score']
    elif three_item_viable:
        chosen_bundle_skus = best_3_item_bundle_details['skus']
        chosen_bundle_type = "3-Item Bundle"
        final_bundle_score = best_3_item_bundle_details['score']
    elif two_item_viable:
        chosen_bundle_skus = best_2_item_bundle_details['skus']
        chosen_bundle_type = "2-Item Bundle"
        final_bundle_score = best_2_item_bundle_details['score']
    
    if not chosen_bundle_skus:
        return {"message": f"No suitable bundle found meeting quality thresholds for '{target_item_name}'. Best 2-item score: {max_2_item_score:.2f}, Best 3-item score: {max_3_item_score:.2f}."}

    bundle_item_details_list = [products_df.loc[sku] for sku in chosen_bundle_skus]
    sum_individual_prices = sum(item.AvgUnitPrice for item in bundle_item_details_list)
    
    def get_main_category(cat_string):
        if pd.isna(cat_string) or not isinstance(cat_string, str): return "Unknown"
        return cat_string.split('/')[0].strip()

    item_margin_flags = [1 if get_main_category(item_detail.get('Category', "Unknown")) in HIGH_MARGIN_CATEGORIES else 0 for item_detail in bundle_item_details_list]
    avg_bundle_margin_flag = np.mean(item_margin_flags) if item_margin_flags else 0
    # print(f"  > Bundle Category Mix: {avg_bundle_margin_flag*100:.0f}% high-margin items.")

    base_discount_rate = 0.15 if len(chosen_bundle_skus) == 3 else 0.10
    margin_based_discount_reduction_factor = avg_bundle_margin_flag * 0.40
    effective_base_discount_rate = base_discount_rate * (1 - margin_based_discount_reduction_factor)
    # print(f"    Base disc: {base_discount_rate:.2%}, Margin factor: {margin_based_discount_reduction_factor:.2%}, Eff. base: {effective_base_discount_rate:.2%}")

    avg_stock_score = np.mean([item.StockLevelScore for item in bundle_item_details_list])
    stock_discount_boost = 0.05 if avg_stock_score > 0.7 else 0.0
    if avg_bundle_margin_flag > 0.5 and stock_discount_boost > 0:
         stock_discount_boost *= 0.5
         # print(f"    Stock boost reduced for high-margin to: {stock_discount_boost:.2%}")

    total_discount_rate = effective_base_discount_rate + stock_discount_boost
    total_discount_rate = max(0.05, min(total_discount_rate, 0.40))
    # print(f"    Total discount rate: {total_discount_rate:.2%}")

    bundle_price = sum_individual_prices * (1 - total_discount_rate)
    savings = sum_individual_prices - bundle_price

    return {
        "bundle_type": chosen_bundle_type,
        "bundle_skus": chosen_bundle_skus,
        "bundle_item_titles": [item.ItemTitle for item in bundle_item_details_list],
        "personalized_score": final_bundle_score,
        "sum_individual_prices": sum_individual_prices,
        "bundle_price": bundle_price,
        "total_discount_applied": total_discount_rate,
        "savings": savings,
        "target_sku_for_reference": target_sku 
    }

# --- 4. EXAMPLE USAGE (EXPANDED DEMONSTRATION) ---
if __name__ == '__main__':
    print("Starting Smart Bundling Engine...")
    if not (os.path.exists(EMBEDDINGS_PATH) and os.path.exists(SKUS_JSON_PATH)):
        print(f"⚠️ Pre-computed embeddings not found. Running one-time pre-computation...")
        if create_and_save_embeddings_utility(): print("✔ Embedding pre-computation successful.")
        else: print("❌ Embedding pre-computation FAILED. Exiting."); exit()
    else: print(f"✔ Pre-computed embeddings found. Loading them.")
            
    master_products_df, user_profiles = load_and_engineer_data(
        ORDERS_FILE_PATH, INVENTORY_FILE_PATH, SUGGESTIONS_FILE_PATH,
        EMBEDDINGS_PATH, SKUS_JSON_PATH
    )
    
    if master_products_df is None or user_profiles is None:
        print("❌ Master feature engineering or user profile creation failed. Exiting.")
        exit()
    if master_products_df.empty or not user_profiles:
        print("❌ Product data or user profiles are empty after loading/engineering. Exiting.")
        exit()

    faiss_index, _ = build_faiss_index_from_loaded_embeddings(master_products_df)
        
    similarity_weights = {
            'user_taste': 0.4, 'price_affinity': 0.2, 'purchase': 0.15,
            'stock_level': 0.1, 'price_context': 0.05,
            'category': 0.05, 'name': 0.05,
        }
    
    # --- Prepare lists for expanded demonstration ---
    try:
        orders_df_for_demo = pd.read_csv(ORDERS_FILE_PATH)
        user_counts = orders_df_for_demo['UserID'].value_counts()
        # Get users who have made at least 3 orders and have a profile
        potential_active_users = user_counts[user_counts >= 3].index.tolist()
        active_user_list = [uid for uid in potential_active_users if uid in user_profiles and user_profiles[uid].get('profile_vector') is not None]
        
        if len(active_user_list) < 2:
            print("❌ Need at least 2 active users with profiles for the comparative demo. Trying with any available users.")
            active_user_list = [uid for uid in user_counts.index.tolist() if uid in user_profiles and user_profiles[uid].get('profile_vector') is not None]
            if len(active_user_list) < 2:
                print("❌ Still not enough users with profiles for comparative demo. Exiting.")
                exit()
        
        print(f"\nFound {len(active_user_list)} active users with profiles for demo.")
        # Select two distinct users for the comparative demo
        user_A_id = active_user_list[0]
        user_B_id = active_user_list[1]
        print(f"Comparative Demo Users: User A ({user_A_id}), User B ({user_B_id})")

    except FileNotFoundError:
        exit(f"Error loading '{ORDERS_FILE_PATH}' for demo user selection.")
    except Exception as e:
        exit(f"Error preparing active user list: {e}")

    try:
        suggestions_df_for_demo = pd.read_csv(SUGGESTIONS_FILE_PATH)
        if 'Item title' not in suggestions_df_for_demo.columns or 'similar_items' not in suggestions_df_for_demo.columns:
            exit(f"Critical columns missing in '{SUGGESTIONS_FILE_PATH}'.")
        
        target_items_with_suggestions = suggestions_df_for_demo.dropna(subset=['similar_items', 'Item title'])
        target_items_with_suggestions = target_items_with_suggestions[target_items_with_suggestions['similar_items'].str.strip() != '']
        
        target_item_names_for_demo_list = [
            name for name in target_items_with_suggestions['Item title'].unique() 
            if name in master_products_df['ItemTitle'].values # Ensure item exists in master_products_df
        ]
        if not target_item_names_for_demo_list:
            exit(f"No items from '{SUGGESTIONS_FILE_PATH}' with 'similar_items' also exist in master product list for demo.")
        print(f"Found {len(target_item_names_for_demo_list)} target items with suggestions for comparative demo.")
        random.shuffle(target_item_names_for_demo_list) # Shuffle for variety
    except FileNotFoundError:
        exit(f"Error loading '{SUGGESTIONS_FILE_PATH}' for demo items.")
    except Exception as e:
        exit(f"Error preparing target item list: {e}")

    # --- Comparative Personalization Demo Loop (up to 100 products) ---
    num_comparative_examples = min(1000, len(target_item_names_for_demo_list))
    print(f"\n\n{'='*70}\n✨ COMPARATIVE PERSONALIZATION DEMO (for {num_comparative_examples} products) ✨\n{'='*70}")

    for i in range(num_comparative_examples):
        target_item_name = target_item_names_for_demo_list[i]
        print(f"\n--- DEMO PRODUCT {i+1} of {num_comparative_examples} ---")
        print(f"🎯 Target Item: '{target_item_name}'")
        print("-" * 50)

        # Recommendation for User A
        print(f"  👤 For User A ({user_A_id}):")
        bundle_A = suggest_smart_bundle_for_user(
            target_item_name=target_item_name, user_id=user_A_id,
            products_df=master_products_df, user_profiles=user_profiles, weights=similarity_weights
        )
        if "error" in bundle_A: print(f"    Error: {bundle_A['error']}")
        elif "message" in bundle_A: print(f"    Message: {bundle_A['message']}")
        elif "bundle_type" in bundle_A:
            print(f"    Recommends: {bundle_A['bundle_type']}")
            additional_titles_A = [title for sku, title in zip(bundle_A['bundle_skus'], bundle_A['bundle_item_titles']) if sku != bundle_A.get('target_sku_for_reference')]
            if additional_titles_A: print(f"    With: {', '.join(additional_titles_A)}")
            else: print("    (Primarily the target item itself)")
            print(f"    Score: {bundle_A['personalized_score']:.3f}, Price: ${bundle_A['bundle_price']:.2f} (Save ${bundle_A['savings']:.2f})")
        else: print("    Unexpected result for User A.")
        
        print("-" * 30)

        # Recommendation for User B
        print(f"  👤 For User B ({user_B_id}):")
        bundle_B = suggest_smart_bundle_for_user(
            target_item_name=target_item_name, user_id=user_B_id,
            products_df=master_products_df, user_profiles=user_profiles, weights=similarity_weights
        )
        if "error" in bundle_B: print(f"    Error: {bundle_B['error']}")
        elif "message" in bundle_B: print(f"    Message: {bundle_B['message']}")
        elif "bundle_type" in bundle_B:
            print(f"    Recommends: {bundle_B['bundle_type']}")
            additional_titles_B = [title for sku, title in zip(bundle_B['bundle_skus'], bundle_B['bundle_item_titles']) if sku != bundle_B.get('target_sku_for_reference')]
            if additional_titles_B: print(f"    With: {', '.join(additional_titles_B)}")
            else: print("    (Primarily the target item itself)")
            print(f"    Score: {bundle_B['personalized_score']:.3f}, Price: ${bundle_B['bundle_price']:.2f} (Save ${bundle_B['savings']:.2f})")
        else: print("    Unexpected result for User B.")
        print("="*70)
# Out:
# 2025-05-25 08:04:27.079949: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748160267.360784      13 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748160267.439598      13 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Starting Smart Bundling Engine...
# ⚠️ Pre-computed embeddings not found. Running one-time pre-computation...
# 🚀 Starting one-time embedding generation for FAISS...
#   > Loading SentenceTransformer model (all-MiniLM-L6-v2) for pre-computation...
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
#   > Encoding 67907 product titles...
# Batches:   0%|          | 0/2123 [00:00<?, ?it/s]
# ✔ Embeddings saved to '/kaggle/working/product_embeddings.npy' & SKU list to '/kaggle/working/product_skus.json'
# ✔ Embedding pre-computation successful.
# 🚀 Loading all data and pre-computed embeddings...
#   > Engineering master product DataFrame...
#     Successfully mapped 67907 pre-computed embeddings.
#   > Calculating stock scores...
#   > Engineering purchase vectors...
# ✔ Master product features complete.
# 🚀 Creating user profile vectors...
# ✔ Created 12942 user profiles.
# 🚀 Building FAISS index from loaded embeddings...
# ✔ FAISS index built with 67907 items.
#
# Found 6499 active users with profiles for demo.
# Comparative Demo Users: User A (44140.0), User B (49464.0)
# Found 6786 target items with suggestions for comparative demo.
#
#
# ======================================================================
# ✨ COMPARATIVE PERSONALIZATION DEMO (for 1000 products) ✨
# ======================================================================
#
# --- DEMO PRODUCT 1 of 1000 ---
# 🎯 Target Item: 'Chiara Ferragni Lip Plumper - Volume Kiss 01 Honey'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Hair Rituel by Sisley Regenerating Hair Care Mask With Botanical Oils 200 ml
#     Score: 0.365, Price: $111.00 (Save $16.59)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Κiko Milano Winged Eyeliner, Hair Rituel by Sisley Precious Hair Care Oilglossiness And Nutrition 100 ml
#     Score: 0.322, Price: $101.99 (Save $15.92)
# ======================================================================
#
# --- DEMO PRODUCT 2 of 1000 ---
# 🎯 Target Item: 'Kiko Milano Curling Top Coat Mascara 11 ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Message: No suitable bundle found meeting quality thresholds for 'Kiko Milano Curling Top Coat Mascara 11 ml'. Best 2-item score: 0.27, Best 3-item score: 0.27.
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Sensai Styling Eyebrow Pencil 01 Dark Brown, Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 11 Le Beige Noisette - Satin
#     Score: 0.391, Price: $66.63 (Save $10.40)
# ======================================================================
#
# --- DEMO PRODUCT 3 of 1000 ---
# 🎯 Target Item: 'Kiko Milano Velvet Passion Matte Lipstick 340 Light Sienna'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Hair Rituel by Sisley Regenerating Hair Care Mask With Botanical Oils 200 ml
#     Score: 0.367, Price: $96.67 (Save $14.44)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Lancôme Lip Idôle Lip Shaper 1,2 gr Red Νow, Lancôme Lip Idôle Lip Shaper 1,2 gr Mahogany Μauve
#     Score: 0.363, Price: $34.84 (Save $7.65)
# ======================================================================
#
# --- DEMO PRODUCT 4 of 1000 ---
# 🎯 Target Item: 'Levi's® ανδρικό T-shirt μονόχρωμο με λογότυπο Relaxed Fit Μαύρο M'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Guess παιδικό τζιν παντελόνι πεντάτσεπο με φθαρμένη όψη και λογότυπο με στρας Denim Blue 10Y, Guess παιδικό τζιν παντελόνι πεντάτσεπο με φθαρμένη όψη και λογότυπο με στρας Denim Blue 12Y
#     Score: 0.456, Price: $98.56 (Save $24.64)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guess παιδικό τζιν παντελόνι πεντάτσεπο με φθαρμένη όψη και λογότυπο με στρας Denim Blue 10Y, Guess παιδικό τζιν παντελόνι πεντάτσεπο με φθαρμένη όψη και λογότυπο με στρας Denim Blue 12Y
#     Score: 0.422, Price: $98.56 (Save $24.64)
# ======================================================================
#
# --- DEMO PRODUCT 5 of 1000 ---
# 🎯 Target Item: 'Clarins ClarinsMen Antiperspirant Deo Roll On 50 ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Lancôme Absolue The Eye Cream Αναζωογονητική Κρέμα Ματιών 20 ml
#     Score: 0.515, Price: $104.75 (Save $9.73)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 2-Item Bundle
#     With: Lancôme Absolue The Eye Cream Αναζωογονητική Κρέμα Ματιών 20 ml
#     Score: 0.423, Price: $104.75 (Save $9.73)
# ======================================================================
#
# --- DEMO PRODUCT 6 of 1000 ---
# 🎯 Target Item: 'Sensai Total Finish Refill 11 gr Almond Beige'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Message: No suitable bundle found meeting quality thresholds for 'Sensai Total Finish Refill 11 gr Almond Beige'. Best 2-item score: 0.24, Best 3-item score: 0.26.
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Clarins One-Step Facial Cleanser Bi-Phase 200 ml, L'Occitane Shea Solid Face Cleanser 75 g
#     Score: 0.335, Price: $64.75 (Save $10.11)
# ======================================================================
#
# --- DEMO PRODUCT 7 of 1000 ---
# 🎯 Target Item: 'Happy Socks unisex κάλτσες "Veggie" Πολύχρωμο 36/40'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Happy Socks unisex κάλτσες "Mushroom" Πολύχρωμο 41-46, Happy Socks unisex κάλτσες "Flower" Πολύχρωμο 36-40
#     Score: 0.443, Price: $21.52 (Save $5.38)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 2-Item Bundle
#     With: Nautica ανδρικό T-shirt με logo print Regular Fit "Miltown" Γκρι Γαλάζιο M
#     Score: 0.526, Price: $38.39 (Save $6.77)
# ======================================================================
#
# --- DEMO PRODUCT 8 of 1000 ---
# 🎯 Target Item: 'Mayoral παιδικά σανδάλια με σχέδιο πλεξούδα και στρας (31-38) Λευκό 31'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Lacoste γυναικείο T-shirt με ριγέ σχέδιο και κεντημένο λογότυπο Regular Fit Ροζ Ανοιχτό 36, Guess γυναικείο T-shirt με λογότυπο  Γαλάζιο M
#     Score: 0.527, Price: $117.60 (Save $29.40)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 2-Item Bundle
#     With: Guess γυναικείο T-shirt με λογότυπο  Γαλάζιο M
#     Score: 0.531, Price: $67.15 (Save $11.85)
# ======================================================================
#
# --- DEMO PRODUCT 9 of 1000 ---
# 🎯 Target Item: 'Shiseido Controlled Chaos Mascaraink Shiseido Controlled Chaos Mascaraink 01 Black Pulse'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Message: No suitable bundle found meeting quality thresholds for 'Shiseido Controlled Chaos Mascaraink Shiseido Controlled Chaos Mascaraink 01 Black Pulse'. Best 2-item score: 0.26, Best 3-item score: 0.26.
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 11 Le Beige Noisette - Satin, Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 829 Le Fuchsia Profond - Satin
#     Score: 0.385, Price: $98.02 (Save $12.74)
# ======================================================================
#
# --- DEMO PRODUCT 10 of 1000 ---
# 🎯 Target Item: 'Prada Luna Rossa Eau de Toilette Prada Luna Rossa Eau de Toilette 50 ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Happy Socks unisex κοντές κάλτσες σε διάφορα σχέδια (Σετ 2 τεμάχια) Μαύρο 41/46, Happy Socks unisex κάλτσες "Techy" Λευκό 41/46
#     Score: 0.386, Price: $72.55 (Save $18.14)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 2-Item Bundle
#     With: Givenchy L'Interdit The Deodorant 100 ml
#     Score: 0.537, Price: $89.19 (Save $13.33)
# ======================================================================
#
# --- DEMO PRODUCT 11 of 1000 ---
# 🎯 Target Item: 'Aldo γυναικεία τσάντα χειρός "Surgoine" Μαύρο ONE SIZE'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Izipizi unisex γυαλιά ηλίου "#H" Μαύρο ONE SIZE
#     Score: 0.318, Price: $79.47 (Save $8.83)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Izipizi unisex γυαλιά ηλίου "#H" Μαύρο ONE SIZE, Lancôme Lip Idôle Lip Shaper 1,2 gr Mahogany Μauve
#     Score: 0.381, Price: $85.14 (Save $21.29)
# ======================================================================
#
# --- DEMO PRODUCT 12 of 1000 ---
# 🎯 Target Item: 'Eva Belle Eyebrow Serum 10 ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Hair Rituel by Sisley The Intense Nutrition Hair Care Mask 190 ml
#     Score: 0.389, Price: $102.89 (Save $9.56)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 11 Le Beige Noisette - Satin, Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 829 Le Fuchsia Profond - Satin
#     Score: 0.406, Price: $80.29 (Save $10.43)
# ======================================================================
#
# --- DEMO PRODUCT 13 of 1000 ---
# 🎯 Target Item: 'JACK & JONES ανδρική denim βερμούδα πεντάτσεπη Relaxed Fit "626" Denim Blue L'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Nautica ανδρικό T-shirt με logo print Regular Fit "Miltown" Κίτρινο L, Happy Socks unisex κοντές κάλτσες σε διάφορα σχέδια (Σετ 2 τεμάχια) Μαύρο 41/46
#     Score: 0.426, Price: $44.85 (Save $11.21)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 2-Item Bundle
#     With: Nautica ανδρικό T-shirt με logo print Regular Fit "Miltown" Γκρι Γαλάζιο M
#     Score: 0.531, Price: $41.98 (Save $7.41)
# ======================================================================
#
# --- DEMO PRODUCT 14 of 1000 ---
# 🎯 Target Item: 'OVS παιδικό σετ ρούχων με μπλούζα και παντελόνι φόρμας Regular Fit Βιολετί 7-8Y'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Geox ανδρικά sneakers "Spherica" Μπεζ 40, Boss Shoes ανδρικά δερμάτινα sneakers Λευκό 43
#     Score: 0.461, Price: $223.84 (Save $55.96)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Happy Socks unisex κάλτσες "Flower" Πολύχρωμο 36-40, Boss Shoes ανδρικά δερμάτινα sneakers Λευκό 43
#     Score: 0.378, Price: $150.62 (Save $37.65)
# ======================================================================
#
# --- DEMO PRODUCT 15 of 1000 ---
# 🎯 Target Item: 'Dior Rouge Dior Balm Universal Lip Balm - Hydrating Floral Lip Care 3,2 gr 001 Diormidnight'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Hair Rituel by Sisley Regenerating Hair Care Mask With Botanical Oils 200 ml
#     Score: 0.368, Price: $123.78 (Save $18.50)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Lancôme Lip Idôle Lip Shaper 1,2 gr Red Νow, Lancôme Lip Idôle Lip Shaper 1,2 gr Mahogany Μauve
#     Score: 0.365, Price: $60.39 (Save $13.26)
# ======================================================================
#
# --- DEMO PRODUCT 16 of 1000 ---
# 🎯 Target Item: 'Gant ανδρικό πουκάμισο button down από λινάρι και βαμβάκι με τσέπη και λογότυπο Regular Fit Πράσινο Ανοιχτό M'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Attrattivo γυναικείο παντελόνι  με ρεβέρ και ελαστική μέση Μπλε Ανοιχτό L, Desigual γυναικείο παντελόνι με floral σχέδιο "Silka" Πράσινο S
#     Score: 0.480, Price: $190.71 (Save $47.68)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Desigual γυναικείο παντελόνι με floral σχέδιο "Silka" Πράσινο S, Happy Socks unisex κάλτσες "Mushroom" Πολύχρωμο 41-46
#     Score: 0.387, Price: $149.42 (Save $37.35)
# ======================================================================
#
# --- DEMO PRODUCT 17 of 1000 ---
# 🎯 Target Item: 'Kiko Milano New Glamour Multi Finish Eyeshadow Palette 03 Burgundy Notes'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Lancôme Absolue The Eye Cream Αναζωογονητική Κρέμα Ματιών 20 ml
#     Score: 0.517, Price: $101.22 (Save $9.40)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 11 Le Beige Noisette - Satin, Lancôme Absolue The Eye Cream Αναζωογονητική Κρέμα Ματιών 20 ml
#     Score: 0.449, Price: $131.40 (Save $17.07)
# ======================================================================
#
# --- DEMO PRODUCT 18 of 1000 ---
# 🎯 Target Item: 'Kiko Milano Unlimited Blush 6 gr 03 Golden Coral'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Message: No suitable bundle found meeting quality thresholds for 'Kiko Milano Unlimited Blush 6 gr 03 Golden Coral'. Best 2-item score: 0.27, Best 3-item score: 0.30.
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 11 Le Beige Noisette - Satin, Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 829 Le Fuchsia Profond - Satin
#     Score: 0.403, Price: $81.85 (Save $12.77)
# ======================================================================
#
# --- DEMO PRODUCT 19 of 1000 ---
# 🎯 Target Item: 'Kiko Milano Smart Colour Blush Kiko Milano Smart Colour Blush 09 Pearly Chocolate'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Message: No suitable bundle found meeting quality thresholds for 'Kiko Milano Smart Colour Blush Kiko Milano Smart Colour Blush 09 Pearly Chocolate'. Best 2-item score: 0.28, Best 3-item score: 0.28.
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Sensai The Lipstick Sensai The Lipstick 10 Ayame Mauve 3,5 gr, Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 11 Le Beige Noisette - Satin
#     Score: 0.393, Price: $90.49 (Save $11.76)
# ======================================================================
#
# --- DEMO PRODUCT 20 of 1000 ---
# 🎯 Target Item: 'Gant γυναικείο αμάνικο μπουφάν μονόχρωμο με καπιτονέ σχέδιο και logo print στο στήθος Μαύρο M'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Happy Socks unisex κάλτσες "Mushroom" Πολύχρωμο 41-46, Guess γυναικείο πορτοφόλι με ανάγλυφο σχέδιο και μεταλλικό λογότυπο "Laurel" Μαύρο ONE SIZE
#     Score: 0.430, Price: $169.10 (Save $42.27)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Happy Socks unisex κάλτσες "Flower" Πολύχρωμο 36-40, Guess γυναικείο πορτοφόλι με ανάγλυφο σχέδιο και μεταλλικό λογότυπο "Laurel" Μαύρο ONE SIZE
#     Score: 0.388, Price: $169.10 (Save $42.27)
# ======================================================================
#
# --- DEMO PRODUCT 21 of 1000 ---
# 🎯 Target Item: 'Sisley So Curl 10 ml Deep Black'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Hair Rituel by Sisley Regenerating Hair Care Mask With Botanical Oils 200 ml
#     Score: 0.367, Price: $134.07 (Save $23.66)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Hair Rituel by Sisley Revitalizing Volumizing Shampoo With Camellia Oil 200 ml, Hair Rituel by Sisley Revitalizing Nourishing Shampoo 200 ml
#     Score: 0.362, Price: $136.92 (Save $21.37)
# ======================================================================
#
# --- DEMO PRODUCT 22 of 1000 ---
# 🎯 Target Item: 'Nautica ανδρικό T-shirt μονόχρωμο με τσέπη Γαλάζιο XXL'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Pepe Jeans ανδρικό τζιν παντελόνι πεντάτσεπο Slim Fit (32L) Denim Blue 34
#     Score: 0.527, Price: $110.29 (Save $19.46)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Hermès Eau de Rhubarbe Écarlate Eau de Cologne 100ml, Happy Socks unisex κάλτσες "Mushroom" Πολύχρωμο 41-46
#     Score: 0.381, Price: $97.99 (Save $21.51)
# ======================================================================
#
# --- DEMO PRODUCT 23 of 1000 ---
# 🎯 Target Item: 'Kocca γυναικείο Τ-shirt με απλικέ πέτρες Λευκό M'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Pepe Jeans ανδρικό τζιν παντελόνι πεντάτσεπο Slim Fit (32L) Denim Blue 34, Guess γυναικείο τζιν παντελόνι καμπάνα πεντάτσεπο με logo patch Regular Fit Denim Blue Ανοιχτό 26W 32L
#     Score: 0.601, Price: $232.90 (Save $41.10)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guess παιδικό τζιν παντελόνι πεντάτσεπο με φθαρμένη όψη και λογότυπο με στρας Denim Blue 10Y, Guess παιδικό τζιν παντελόνι πεντάτσεπο με φθαρμένη όψη και λογότυπο με στρας Denim Blue 12Y
#     Score: 0.442, Price: $125.60 (Save $31.40)
# ======================================================================
#
# --- DEMO PRODUCT 24 of 1000 ---
# 🎯 Target Item: 'L'Occitane Eau De Cedrat After-Shave Cream Gel 75 ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Hermès Eau de Rhubarbe Écarlate Eau de Cologne 100ml, Hermès Eau de Basilic Pourpre Eau de Cologne 200ml
#     Score: 0.398, Price: $265.15 (Save $41.38)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Hermès Eau de Basilic Pourpre Eau de Cologne 200ml, L'Occitane Shea Butter Hand Cream 150ml
#     Score: 0.421, Price: $210.45 (Save $32.85)
# ======================================================================
#
# --- DEMO PRODUCT 25 of 1000 ---
# 🎯 Target Item: 'Dior Lip Glow Oil Nourishing Glossy Lip Oil - Color-Awakening 6 ml 096 Pink Pop'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Message: No suitable bundle found meeting quality thresholds for 'Dior Lip Glow Oil Nourishing Glossy Lip Oil - Color-Awakening 6 ml 096 Pink Pop'. Best 2-item score: 0.25, Best 3-item score: 0.27.
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Lancôme Lip Idôle Lip Shaper 1,2 gr Red Νow, Lancôme Lip Idôle Lip Shaper 1,2 gr Mahogany Μauve
#     Score: 0.361, Price: $67.34 (Save $16.83)
# ======================================================================
#
# --- DEMO PRODUCT 26 of 1000 ---
# 🎯 Target Item: 'Gant ανδρικό μαγιό σορτς με logo print Regular Fit Μαύρο XL'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Geox ανδρικά sneakers "Spherica" Μπεζ 40, Hoff γυναικεία sneakers "Tiryns" Ασημί 39
#     Score: 0.502, Price: $191.60 (Save $47.90)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Hermès Eau de Rhubarbe Écarlate Eau de Cologne 100ml, Hermès Eau de Basilic Pourpre Eau de Cologne 200ml
#     Score: 0.393, Price: $259.84 (Save $57.04)
# ======================================================================
#
# --- DEMO PRODUCT 27 of 1000 ---
# 🎯 Target Item: 'OVS παιδική μπλούζα μακρυμάνικη με dinosaur print Πράσινο 3-4Y'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Happy Socks unisex κάλτσες "Octopus" Μαύρο 36-40, Happy Socks unisex κάλτσες "Octopus" Μαύρο 41-46
#     Score: 0.393, Price: $18.72 (Save $4.68)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Desigual γυναικείο backpack "Blackwell Sumy" Μαύρο ONE SIZE, Aldo γυναικείο backpack "Veraley" Μπεζ ONE SIZE
#     Score: 0.358, Price: $67.34 (Save $16.83)
# ======================================================================
#
# --- DEMO PRODUCT 28 of 1000 ---
# 🎯 Target Item: 'Dior Addict Lip Glow 48-Hour Hydrating Lip Balm - pH-Activated Color 3,2 gr 015 Cherry Cool Undertone'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Hair Rituel by Sisley Regenerating Hair Care Mask With Botanical Oils 200 ml
#     Score: 0.365, Price: $117.67 (Save $20.76)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Kiko Milano Eyebrow Designer Gel Mascara, Hair Rituel by Sisley Precious Hair Care Oilglossiness And Nutrition 100 ml
#     Score: 0.319, Price: $110.38 (Save $17.23)
# ======================================================================
#
# --- DEMO PRODUCT 29 of 1000 ---
# 🎯 Target Item: 'Nautica ανδρικό T-shirt με logo print Regular Fit "Cook" Μπλε Σκούρο L'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Pepe Jeans ανδρικό τζιν παντελόνι πεντάτσεπο Slim Fit (32L) Denim Blue 34
#     Score: 0.525, Price: $121.50 (Save $13.50)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Hermès Eau de Rhubarbe Écarlate Eau de Cologne 100ml, Happy Socks unisex κάλτσες "Mushroom" Πολύχρωμο 41-46
#     Score: 0.376, Price: $102.30 (Save $22.45)
# ======================================================================
#
# --- DEMO PRODUCT 30 of 1000 ---
# 🎯 Target Item: 'Selene γυναικείος κορσές ''903 Control'' Μπεζ XXL'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Happy Socks unisex κοντές κάλτσες σε διάφορα σχέδια (Σετ 2 τεμάχια) Μαύρο 41/46, Happy Socks unisex κάλτσες "Mushroom" Πολύχρωμο 41-46
#     Score: 0.407, Price: $31.38 (Save $7.84)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Happy Socks unisex κοντές κάλτσες σε διάφορα σχέδια (Σετ 2 τεμάχια) Μαύρο 41/46, Happy Socks unisex κάλτσες "Mushroom" Πολύχρωμο 41-46
#     Score: 0.368, Price: $31.38 (Save $7.84)
# ======================================================================
#
# --- DEMO PRODUCT 31 of 1000 ---
# 🎯 Target Item: 'Lauren Ralph Lauren γυναικείο T-shirt με graphic logo από τρουκς Relaxed Fit Κρέμ M'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Pepe Jeans ανδρικό τζιν παντελόνι πεντάτσεπο Slim Fit (32L) Denim Blue 34
#     Score: 0.529, Price: $154.35 (Save $17.15)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guess παιδικό τζιν παντελόνι πεντάτσεπο με φθαρμένη όψη και λογότυπο με στρας Denim Blue 10Y, Guess παιδικό τζιν παντελόνι πεντάτσεπο με φθαρμένη όψη και λογότυπο με στρας Denim Blue 12Y
#     Score: 0.424, Price: $131.60 (Save $32.90)
# ======================================================================
#
# --- DEMO PRODUCT 32 of 1000 ---
# 🎯 Target Item: 'Guerlain Les Légendaires L'Instant de Guerlain Eau de Parfum 75 ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Hermès Eau de Rhubarbe Écarlate Eau de Cologne 100ml
#     Score: 0.396, Price: $192.98 (Save $17.93)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Hermès Eau de Rhubarbe Écarlate Eau de Cologne 100ml, Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 11 Le Beige Noisette - Satin
#     Score: 0.402, Price: $220.15 (Save $28.61)
# ======================================================================
#
# --- DEMO PRODUCT 33 of 1000 ---
# 🎯 Target Item: 'Nautica γυναικείο mini φόρεμα με γιακά και contrast λεπτομέρεια με ριγέ σχέδιο  Μπλε Σκούρο S'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Guess γυναικεία τσάντα ώμου μονόχρωμη με μεταλλικό λογότυπο "Sora" Μαύρο ONE SIZE, Guess γυναικεία τσάντα ώμου με all-over ανάγλυφο σχέδιο και μεταλλικό λογότυπο "Cresidia Peony" Μαύρο ONE SIZE
#     Score: 0.614, Price: $213.10 (Save $53.27)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guess γυναικεία τσάντα ώμου με all-over ανάγλυφο σχέδιο και μεταλλικό λογότυπο "Cresidia Peony" Μαύρο ONE SIZE, Furla γυναικεία δερμάτινη τσάντα ώμου Μαύρο ONE SIZE
#     Score: 0.381, Price: $375.37 (Save $93.84)
# ======================================================================
#
# --- DEMO PRODUCT 34 of 1000 ---
# 🎯 Target Item: 'Camper γυναικεία πέδιλα με φιόγκο "Twins" Μαύρο 38'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Guess γυναικεία τσάντα ώμου μονόχρωμη με μεταλλικό λογότυπο "Sora" Μαύρο ONE SIZE
#     Score: 0.555, Price: $164.05 (Save $28.95)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guess γυναικεία τσάντα ώμου μονόχρωμη με μεταλλικό λογότυπο "Sora" Μαύρο ONE SIZE, Furla γυναικεία δερμάτινη τσάντα ώμου Μαύρο ONE SIZE
#     Score: 0.373, Price: $406.67 (Save $101.67)
# ======================================================================
#
# --- DEMO PRODUCT 35 of 1000 ---
# 🎯 Target Item: 'Dior Diorshow 5 Couleurs – Cannage Limited Edition Long-Wearing Eyeshadow Wardrobe 7 gr 557 Brown Cachemire'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Nautica ανδρικό T-shirt με logo print Regular Fit "Miltown" Κίτρινο L, Nautica ανδρικό T-shirt μονόχρωμο με τσέπη Γαλάζιο XXL
#     Score: 0.442, Price: $102.92 (Save $25.73)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 2-Item Bundle
#     With: Nautica ανδρικό T-shirt με logo print Regular Fit "Miltown" Γκρι Γαλάζιο M
#     Score: 0.522, Price: $95.97 (Save $16.94)
# ======================================================================
#
# --- DEMO PRODUCT 36 of 1000 ---
# 🎯 Target Item: 'Dsquared2 Wood for Her EdT 30ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Coccinelle γυναικεία δερμάτινη τσάντα crossbody με μεταλλικό λογότυπο  Μαύρο ONE SIZE, Valentino γυναικείο mini bag με καπιτονέ σχέδιο και μεταλλικό λογότυπο "Beauty Petal" Μαύρο ONE SIZE
#     Score: 0.454, Price: $190.83 (Save $47.71)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Valentino γυναικείο mini bag με καπιτονέ σχέδιο και μεταλλικό λογότυπο "Beauty Petal" Μαύρο ONE SIZE, L'Occitane Shea Butter Hand Cream 150ml
#     Score: 0.429, Price: $100.49 (Save $22.06)
# ======================================================================
#
# --- DEMO PRODUCT 37 of 1000 ---
# 🎯 Target Item: 'Guerlain Terracotta Le Teint Healthy Glow Natural Perfection Foundation 24H Wear Guerlain Terracotta Le Teint Healthy Glow Natural Perfection Foundation 24H Wear - No Transfer - The Perfection Of A Foundation, The Lightness Of A Powder 1N Neutral 35 ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Hair Rituel by Sisley Regenerating Hair Care Mask With Botanical Oils 200 ml
#     Score: 0.365, Price: $147.73 (Save $22.07)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 11 Le Beige Noisette - Satin, Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 829 Le Fuchsia Profond - Satin
#     Score: 0.407, Price: $129.95 (Save $16.89)
# ======================================================================
#
# --- DEMO PRODUCT 38 of 1000 ---
# 🎯 Target Item: 'Clarins Masvelt Advanced Body Shaping Cream 200 ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Lancôme Absolue The Eye Cream Αναζωογονητική Κρέμα Ματιών 20 ml
#     Score: 0.520, Price: $127.84 (Save $11.88)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: L'Occitane Shea Butter Hand Cream 150ml, Lancôme Absolue The Eye Cream Αναζωογονητική Κρέμα Ματιών 20 ml
#     Score: 0.450, Price: $145.90 (Save $18.96)
# ======================================================================
#
# --- DEMO PRODUCT 39 of 1000 ---
# 🎯 Target Item: 'Lacoste ανδρικό σετ μποξεράκια με μικροσχέδιο (3 τεμάχια) Μπλε Ραφ L'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: OVS παιδικό denim παντελόνι με ελαστική μέση Μπλε Σκούρο 11-12Y, Geox ανδρικά sneakers "Spherica" Μπεζ 40
#     Score: 0.472, Price: $125.50 (Save $31.37)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Hermès Eau de Basilic Pourpre Eau de Cologne 200ml, OVS παιδικό denim παντελόνι με ελαστική μέση Μπλε Σκούρο 11-12Y
#     Score: 0.420, Price: $195.90 (Save $48.97)
# ======================================================================
#
# --- DEMO PRODUCT 40 of 1000 ---
# 🎯 Target Item: 'Kiko Milano Velvet Passion Matte Lipstick 314 Plum'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Error: Item 'Kiko Milano Velvet Passion Matte Lipstick 314 Plum' has no pre-defined 'similar_items' to create bundles from.
# ------------------------------
#   👤 For User B (49464.0):
#     Error: Item 'Kiko Milano Velvet Passion Matte Lipstick 314 Plum' has no pre-defined 'similar_items' to create bundles from.
# ======================================================================
#
# --- DEMO PRODUCT 41 of 1000 ---
# 🎯 Target Item: 'Guerlain Abeille Royale Uv Skin Defense Protective Fluid Youthful Radiance 50 ml Spf 50 / Pa++++'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Message: No suitable bundle found meeting quality thresholds for 'Guerlain Abeille Royale Uv Skin Defense Protective Fluid Youthful Radiance 50 ml Spf 50 / Pa++++'. Best 2-item score: 0.26, Best 3-item score: 0.28.
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: L'Occitane Shea Butter Hand Cream 150ml, L'Occitane Shea Butter Hand Cream 30 ml
#     Score: 0.399, Price: $90.61 (Save $11.77)
# ======================================================================
#
# --- DEMO PRODUCT 42 of 1000 ---
# 🎯 Target Item: 'Calvin Klein Everyone Eau de Toilette Calvin Klein Everyone Eau de Toilette 100 ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Happy Socks unisex κοντές κάλτσες σε διάφορα σχέδια (Σετ 2 τεμάχια) Μαύρο 41/46, Happy Socks unisex κάλτσες "Techy" Λευκό 41/46
#     Score: 0.379, Price: $51.18 (Save $12.79)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 2-Item Bundle
#     With: Givenchy L'Interdit The Deodorant 100 ml
#     Score: 0.557, Price: $65.95 (Save $9.85)
# ======================================================================
#
# --- DEMO PRODUCT 43 of 1000 ---
# 🎯 Target Item: 'JACK & JONES ανδρικό μαγιό σορτς με all-over print Μοβ L'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Geox ανδρικά sneakers "Spherica" Μπεζ 40, Boss Shoes ανδρικά δερμάτινα sneakers Λευκό 43
#     Score: 0.460, Price: $222.69 (Save $55.67)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Happy Socks unisex κάλτσες "Flower" Πολύχρωμο 36-40, Boss Shoes ανδρικά δερμάτινα sneakers Λευκό 43
#     Score: 0.376, Price: $149.46 (Save $37.37)
# ======================================================================
#
# --- DEMO PRODUCT 44 of 1000 ---
# 🎯 Target Item: 'Happy Socks unisex κοντές κάλτσες σε διάφορα σχέδια (Σετ 2 τεμάχια) Μαύρο 41/46'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Nautica ανδρικό T-shirt με logo print Regular Fit "Miltown" Κίτρινο L, Happy Socks unisex κάλτσες "Mushroom" Πολύχρωμο 41-46
#     Score: 0.425, Price: $40.03 (Save $10.01)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 2-Item Bundle
#     With: Nautica ανδρικό T-shirt με logo print Regular Fit "Miltown" Γκρι Γαλάζιο M
#     Score: 0.524, Price: $41.37 (Save $7.30)
# ======================================================================
#
# --- DEMO PRODUCT 45 of 1000 ---
# 🎯 Target Item: 'Coccinelle γυναικεία δερμάτινη τσάντα crossbody με μεταλλικό λογότυπο  Μαύρο ONE SIZE'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Guess γυναικείο πορτοφόλι με all-over ανάγλυφο σχέδιο και μεταλλικό λογότυπο "Cresidia" Μαύρο ONE SIZE, Guess γυναικείο πορτοφόλι με ανάγλυφο σχέδιο και μεταλλικό λογότυπο "Laurel" Μαύρο ONE SIZE
#     Score: 0.460, Price: $202.32 (Save $50.58)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guess γυναικείο πορτοφόλι με all-over ανάγλυφο σχέδιο και μεταλλικό λογότυπο "Cresidia" Μαύρο ONE SIZE, Guess γυναικείο πορτοφόλι με ανάγλυφο σχέδιο και μεταλλικό λογότυπο "Laurel" Μαύρο ONE SIZE
#     Score: 0.410, Price: $202.32 (Save $50.58)
# ======================================================================
#
# --- DEMO PRODUCT 46 of 1000 ---
# 🎯 Target Item: 'Timberland ανδρική cargo βερμούδα "Brookline" Μπλε Σκούρο 34'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Nautica ανδρικό T-shirt με logo print Regular Fit "Miltown" Γκρι Γαλάζιο M, Nautica ανδρικό T-shirt με logo print Regular Fit "Miltown" Κίτρινο L
#     Score: 0.412, Price: $96.55 (Save $24.14)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 2-Item Bundle
#     With: Nautica ανδρικό T-shirt με logo print Regular Fit "Miltown" Γκρι Γαλάζιο M
#     Score: 0.524, Price: $78.79 (Save $13.90)
# ======================================================================
#
# --- DEMO PRODUCT 47 of 1000 ---
# 🎯 Target Item: 'Faber-Castell Μαρκαδόρος uπογράμμισης Textliner 46 Metallic magnificent blue'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Faber-Castell Ανταλλακτική Ξύστρα για Perfect Pencil, Faber-Castell μολύβι Grip Β Σιέλ
#     Score: 0.407, Price: $6.54 (Save $1.64)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Faber-Castell Ανταλλακτική Ξύστρα για Perfect Pencil, Faber-Castell μολύβι Grip Β Σιέλ
#     Score: 0.400, Price: $6.54 (Save $1.64)
# ======================================================================
#
# --- DEMO PRODUCT 48 of 1000 ---
# 🎯 Target Item: 'Estée Lauder Pure Color Envy Luxe Eyeshadow Quad Refills Estée Lauder Pure Color Envy Luxe Eyeshadow Quad Refills Desert Dunes 6g'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Hair Rituel by Sisley The Intense Nutrition Hair Care Mask 190 ml
#     Score: 0.380, Price: $120.59 (Save $18.02)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 11 Le Beige Noisette - Satin, Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 829 Le Fuchsia Profond - Satin
#     Score: 0.426, Price: $101.10 (Save $15.78)
# ======================================================================
#
# --- DEMO PRODUCT 49 of 1000 ---
# 🎯 Target Item: 'Kiko Milano Lasting Matte Veil 02 Cappuccino'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Message: No suitable bundle found meeting quality thresholds for 'Kiko Milano Lasting Matte Veil 02 Cappuccino'. Best 2-item score: 0.23, Best 3-item score: 0.25.
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Diοr Vernis Nail Polish with Gel Effect and Couture Color 648 Mirage, Kiko Milano Eyebrow Designer Gel Mascara
#     Score: 0.335, Price: $38.83 (Save $5.05)
# ======================================================================
#
# --- DEMO PRODUCT 50 of 1000 ---
# 🎯 Target Item: 'Lee® ανδρικό τζιν παντελόνι πεντάτσεπο Regular Fit "Daren" Λαδί 34W 32L'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Happy Socks unisex κοντές κάλτσες σε διάφορα σχέδια (Σετ 2 τεμάχια) Μαύρο 41/46, Happy Socks unisex κάλτσες "Techy" Λευκό 41/46
#     Score: 0.393, Price: $91.02 (Save $22.76)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 2-Item Bundle
#     With: Givenchy L'Interdit The Deodorant 100 ml
#     Score: 0.524, Price: $115.56 (Save $10.05)
# ======================================================================
#
# --- DEMO PRODUCT 51 of 1000 ---
# 🎯 Target Item: 'Estée Lauder Beautiful Magnolia L'eau Eau de Toilette 50ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Happy Socks unisex κοντές κάλτσες σε διάφορα σχέδια (Σετ 2 τεμάχια) Μαύρο 41/46, Happy Socks unisex κάλτσες "Mushroom" Πολύχρωμο 41-46
#     Score: 0.396, Price: $68.70 (Save $15.08)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Happy Socks unisex κοντές κάλτσες σε διάφορα σχέδια (Σετ 2 τεμάχια) Μαύρο 41/46, Happy Socks unisex κάλτσες "Mushroom" Πολύχρωμο 41-46
#     Score: 0.357, Price: $68.70 (Save $15.08)
# ======================================================================
#
# --- DEMO PRODUCT 52 of 1000 ---
# 🎯 Target Item: 'Rabanne Lady Million Fabulous Eau de Parfum 80ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Hermès Eau de Citron Noir Eau de Cologne 50ml, Hermès Eau de Rhubarbe Écarlate Eau de Cologne 100ml
#     Score: 0.411, Price: $213.27 (Save $46.82)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Hermès Eau de Rhubarbe Écarlate Eau de Cologne 100ml, Hermès Eau de Basilic Pourpre Eau de Cologne 200ml
#     Score: 0.404, Price: $315.75 (Save $69.31)
# ======================================================================
#
# --- DEMO PRODUCT 53 of 1000 ---
# 🎯 Target Item: 'Dior Sauvage After-Shave Balm Scented After-Shave Balm - Soothes and Moisturizes 100 ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Happy Socks unisex κοντές κάλτσες σε διάφορα σχέδια (Σετ 2 τεμάχια) Μαύρο 41/46, Happy Socks unisex κάλτσες "Techy" Λευκό 41/46
#     Score: 0.374, Price: $58.80 (Save $12.91)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Givenchy Irresistible The Deodorant 100 ml, Hair Rituel by Sisley Gentle Purifying Shampoo 200 ml
#     Score: 0.432, Price: $111.86 (Save $14.54)
# ======================================================================
#
# --- DEMO PRODUCT 54 of 1000 ---
# 🎯 Target Item: 'Guerlain Terracotta Blush - The Healthy Glow Powder Blush 5 gr 000 Pearly Beige'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Sensai The Lipstick Sensai The Lipstick 10 Ayame Mauve 3,5 gr, Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 829 Le Fuchsia Profond - Satin
#     Score: 0.303, Price: $126.30 (Save $19.71)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 11 Le Beige Noisette - Satin, Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 829 Le Fuchsia Profond - Satin
#     Score: 0.436, Price: $110.25 (Save $17.21)
# ======================================================================
#
# --- DEMO PRODUCT 55 of 1000 ---
# 🎯 Target Item: 'Kiko Milano Smart Fusion Lip Pencil 0,9 gr 20 Light Rosy Mauve'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Hair Rituel by Sisley Regenerating Hair Care Mask With Botanical Oils 200 ml
#     Score: 0.366, Price: $93.41 (Save $16.48)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 2-Item Bundle
#     With: Lancôme Lip Idôle Lip Shaper 1,2 gr Mahogany Μauve
#     Score: 0.389, Price: $19.65 (Save $3.47)
# ======================================================================
#
# --- DEMO PRODUCT 56 of 1000 ---
# 🎯 Target Item: 'Timberland ανδρικό T-shirt βαμβακερό μονόχρωμο με contrast logo print Μουσταρδί XXL'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Guess παιδικό τζιν παντελόνι πεντάτσεπο με φθαρμένη όψη και λογότυπο με στρας Denim Blue 10Y, Guess παιδικό τζιν παντελόνι πεντάτσεπο με φθαρμένη όψη και λογότυπο με στρας Denim Blue 12Y
#     Score: 0.453, Price: $96.80 (Save $24.20)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guess παιδικό τζιν παντελόνι πεντάτσεπο με φθαρμένη όψη και λογότυπο με στρας Denim Blue 10Y, Guess παιδικό τζιν παντελόνι πεντάτσεπο με φθαρμένη όψη και λογότυπο με στρας Denim Blue 12Y
#     Score: 0.419, Price: $96.80 (Save $24.20)
# ======================================================================
#
# --- DEMO PRODUCT 57 of 1000 ---
# 🎯 Target Item: 'OVS παιδικό σορτς με lettering print Slim Fit Μαύρο 11-12Y'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Geox ανδρικά sneakers "Spherica" Μπεζ 40, Hoff γυναικεία sneakers "Tiryns" Ασημί 39
#     Score: 0.503, Price: $164.21 (Save $41.05)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Happy Socks unisex κάλτσες "Mushroom" Πολύχρωμο 41-46, Happy Socks unisex κάλτσες "Flower" Πολύχρωμο 36-40
#     Score: 0.379, Price: $18.48 (Save $4.62)
# ======================================================================
#
# --- DEMO PRODUCT 58 of 1000 ---
# 🎯 Target Item: 'Kiko Milano New Universal Stick Concealer 03 Light Neutral'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Sensai The Lipstick Sensai The Lipstick 10 Ayame Mauve 3,5 gr, Κiko Milano Winged Eyeliner
#     Score: 0.304, Price: $63.91 (Save $14.03)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 11 Le Beige Noisette - Satin, Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 829 Le Fuchsia Profond - Satin
#     Score: 0.394, Price: $80.39 (Save $12.55)
# ======================================================================
#
# --- DEMO PRODUCT 59 of 1000 ---
# 🎯 Target Item: 'DKNY γυναικεία τσάντα ώμου tote με ανάγλυφο λογότυπο "Charlie" Υπόλευκο ONE SIZE'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Guess γυναικεία τσάντα ώμου μονόχρωμη με μεταλλικό λογότυπο "Sora" Μαύρο ONE SIZE, Guess γυναικεία τσάντα ώμου με all-over ανάγλυφο σχέδιο και μεταλλικό λογότυπο "Cresidia Peony" Μαύρο ONE SIZE
#     Score: 0.665, Price: $319.50 (Save $79.88)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guess γυναικεία τσάντα ώμου με all-over ανάγλυφο σχέδιο και μεταλλικό λογότυπο "Cresidia Peony" Μαύρο ONE SIZE, Furla γυναικεία δερμάτινη τσάντα ώμου Μαύρο ONE SIZE
#     Score: 0.432, Price: $481.77 (Save $120.44)
# ======================================================================
#
# --- DEMO PRODUCT 60 of 1000 ---
# 🎯 Target Item: 'Kiko Milano Rectangular Foundation Sponge'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Hair Rituel by Sisley Regenerating Hair Care Mask With Botanical Oils 200 ml
#     Score: 0.358, Price: $94.92 (Save $14.18)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 11 Le Beige Noisette - Satin, Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 829 Le Fuchsia Profond - Satin
#     Score: 0.392, Price: $76.24 (Save $9.91)
# ======================================================================
#
# --- DEMO PRODUCT 61 of 1000 ---
# 🎯 Target Item: 'Kiko Milano Flawless Fusion Bronzer Powder Kiko Milano Flawless Fusion Bronzer Powder 03 Cinnamon'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Message: No suitable bundle found meeting quality thresholds for 'Kiko Milano Flawless Fusion Bronzer Powder Kiko Milano Flawless Fusion Bronzer Powder 03 Cinnamon'. Best 2-item score: 0.27, Best 3-item score: 0.28.
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Sensai The Lipstick Sensai The Lipstick 10 Ayame Mauve 3,5 gr, Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 11 Le Beige Noisette - Satin
#     Score: 0.386, Price: $96.39 (Save $12.52)
# ======================================================================
#
# --- DEMO PRODUCT 62 of 1000 ---
# 🎯 Target Item: 'Orsay γυναικείο σακάκι μονόχρωμο με τσέπες στο πλάι Μπλε 40'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Guess γυναικείο πορτοφόλι με ανάγλυφο σχέδιο και μεταλλικό λογότυπο "Laurel" Μαύρο ONE SIZE, Furla γυναικεία δερμάτινη τσάντα ώμου Μαύρο ONE SIZE
#     Score: 0.446, Price: $324.26 (Save $81.06)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guess γυναικείο πορτοφόλι με ανάγλυφο σχέδιο και μεταλλικό λογότυπο "Laurel" Μαύρο ONE SIZE, Furla γυναικεία δερμάτινη τσάντα ώμου Μαύρο ONE SIZE
#     Score: 0.390, Price: $324.26 (Save $81.06)
# ======================================================================
#
# --- DEMO PRODUCT 63 of 1000 ---
# 🎯 Target Item: 'Dsquared2 Icon After Shave Balm Tube 100 ml'
# ...
#
# --- DEMO PRODUCT 979 of 1000 ---
# 🎯 Target Item: 'Versace Eros Pour Homme Eau de Parfum Versace Eros Pour Homme Eau de Parfum 100 ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Happy Socks unisex κοντές κάλτσες σε διάφορα σχέδια (Σετ 2 τεμάχια) Μαύρο 41/46, Happy Socks unisex κάλτσες "Techy" Λευκό 41/46
#     Score: 0.381, Price: $90.61 (Save $19.89)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 2-Item Bundle
#     With: Givenchy L'Interdit The Deodorant 100 ml
#     Score: 0.540, Price: $111.93 (Save $10.40)
# ======================================================================
#
# --- DEMO PRODUCT 980 of 1000 ---
# 🎯 Target Item: 'Κiko Milano Volumeyes + Mascara 11 ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Hair Rituel by Sisley Regenerating Hair Care Mask With Botanical Oils 200 ml
#     Score: 0.370, Price: $100.83 (Save $15.07)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 11 Le Beige Noisette - Satin, Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 829 Le Fuchsia Profond - Satin
#     Score: 0.407, Price: $82.25 (Save $10.69)
# ======================================================================
#
# --- DEMO PRODUCT 981 of 1000 ---
# 🎯 Target Item: 'Clarins Re-Boost Matte Hydra-Matifying Cream 50 ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Message: No suitable bundle found meeting quality thresholds for 'Clarins Re-Boost Matte Hydra-Matifying Cream 50 ml'. Best 2-item score: 0.23, Best 3-item score: 0.24.
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Dior Solar The Protective Creme SPF 50 High-Protection Sunscreen for Body 150 ml, Sisley Sisleÿa L'Intégral Anti-Âge Eye and Lip Contour Cream 15 ml
#     Score: 0.341, Price: $209.53 (Save $32.70)
# ======================================================================
#
# --- DEMO PRODUCT 982 of 1000 ---
# 🎯 Target Item: 'Lancôme Rénergie Multi Lift Nuit 50 ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Message: No suitable bundle found meeting quality thresholds for 'Lancôme Rénergie Multi Lift Nuit 50 ml'. Best 2-item score: 0.25, Best 3-item score: 0.27.
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: L'Occitane Shea Butter Hand Cream 150ml, L'Occitane Shea Butter Hand Cream 30 ml
#     Score: 0.394, Price: $118.66 (Save $15.42)
# ======================================================================
#
# --- DEMO PRODUCT 983 of 1000 ---
# 🎯 Target Item: 'Shiseido Expert Sun Protector Lotion SPF50+ 300ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Mayoral βρεφική πετσέτα παραλίας με print  Ροζ ONE SIZE, Mayoral βρεφική πετσέτα παραλίας με print  Κόκκινο ONE SIZE
#     Score: 0.407, Price: $95.21 (Save $20.90)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Mayoral βρεφική πετσέτα παραλίας με print  Ροζ ONE SIZE, Mayoral βρεφική πετσέτα παραλίας με print  Κόκκινο ONE SIZE
#     Score: 0.384, Price: $95.21 (Save $20.90)
# ======================================================================
#
# --- DEMO PRODUCT 984 of 1000 ---
# 🎯 Target Item: 'Lacoste γυναικεία μπλούζα πόλο κοντομάνικη με contrast trims και κεντημένο λογότυπο Slim Fit Μπλε Σκούρο 40'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Lacoste γυναικεία τσάντα ώμου "Concept Zip Tote" Καμηλό ONE SIZE, OVS παιδικό βαμβακερό denim σορτς πεντάτσεπο μονόχρωμο με ελαστική μέση Denim Blue Ανοιχτό 12-13Y
#     Score: 0.496, Price: $172.78 (Save $43.20)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: OVS παιδικό βαμβακερό denim σορτς πεντάτσεπο ψηλόμεσο με ελαστική μέση Denim Blue 12-13Y, OVS παιδικό βαμβακερό denim σορτς πεντάτσεπο ψηλόμεσο με ελαστική μέση Denim Blue 13-14Y
#     Score: 0.420, Price: $108.77 (Save $27.19)
# ======================================================================
#
# --- DEMO PRODUCT 985 of 1000 ---
# 🎯 Target Item: 'Estée Lauder Double Wear Stay-In-Place Makeup SPF 10 1W0 Warm Porcelain'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Message: No suitable bundle found meeting quality thresholds for 'Estée Lauder Double Wear Stay-In-Place Makeup SPF 10 1W0 Warm Porcelain'. Best 2-item score: 0.22, Best 3-item score: 0.24.
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Clarins Ever Bronze Compact Powder Clarins Ever Bronze Compact Powder 02 Medium, Clarins Ever Matte Compact Powder 03 Light Medium
#     Score: 0.415, Price: $98.75 (Save $12.83)
# ======================================================================
#
# --- DEMO PRODUCT 986 of 1000 ---
# 🎯 Target Item: 'Estée Lauder Pure Color Crème Lipstick 320 Defiant Coral'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Hair Rituel by Sisley The Intense Nutrition Hair Care Mask 190 ml
#     Score: 0.380, Price: $117.28 (Save $17.52)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Hair Rituel by Sisley Hair Protective Fluid 150 ml, Hair Rituel by Sisley The Intense Nutrition Hair Care Mask 190 ml
#     Score: 0.351, Price: $152.28 (Save $33.43)
# ======================================================================
#
# --- DEMO PRODUCT 987 of 1000 ---
# 🎯 Target Item: 'Clarins BB Skin Detox Fluid SPF 25 Clarins BB Skin Detox Fluid SPF 25 45 ml 00 Fair'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Message: No suitable bundle found meeting quality thresholds for 'Clarins BB Skin Detox Fluid SPF 25 Clarins BB Skin Detox Fluid SPF 25 45 ml 00 Fair'. Best 2-item score: 0.22, Best 3-item score: 0.24.
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Clarins One-Step Facial Cleanser Bi-Phase 200 ml, Kiko Milano Unforgettable Waterproof Mascara 11 ml
#     Score: 0.349, Price: $60.15 (Save $7.82)
# ======================================================================
#
# --- DEMO PRODUCT 988 of 1000 ---
# 🎯 Target Item: 'Valentino γυναικείο πορτοφόλι καπιτονέ με μεταλλικό λογότυπο "Petal" Μαύρο ONE SIZE'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Guess γυναικεία τσάντα ώμου μονόχρωμη με μεταλλικό λογότυπο "Sora" Μαύρο ONE SIZE, Guess γυναικεία τσάντα ώμου με all-over ανάγλυφο σχέδιο και μεταλλικό λογότυπο "Cresidia Peony" Μαύρο ONE SIZE
#     Score: 0.610, Price: $202.30 (Save $50.57)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guess γυναικείο πορτοφόλι με all-over ανάγλυφο σχέδιο και μεταλλικό λογότυπο "Cresidia" Μαύρο ONE SIZE, Guess γυναικείο πορτοφόλι με ανάγλυφο σχέδιο και μεταλλικό λογότυπο "Laurel" Μαύρο ONE SIZE
#     Score: 0.462, Price: $120.21 (Save $30.05)
# ======================================================================
#
# --- DEMO PRODUCT 989 of 1000 ---
# 🎯 Target Item: 'L'Occitane Cherry Blossom Hand Cream 30 ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Message: No suitable bundle found meeting quality thresholds for 'L'Occitane Cherry Blossom Hand Cream 30 ml'. Best 2-item score: 0.21, Best 3-item score: 0.23.
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Kiko Milano New Green Me Gentle Facial Cleanser - Edition 2020, Hair Rituel by Sisley Revitalizing Fortifying Serum for the Scalp 60 ml
#     Score: 0.300, Price: $182.54 (Save $28.49)
# ======================================================================
#
# --- DEMO PRODUCT 990 of 1000 ---
# 🎯 Target Item: 'Levi's® γυναικείο T-shirt μονόχρωμο "The Perfect Tee" Λευκό S'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Guess γυναικείο τζιν παντελόνι καμπάνα πεντάτσεπο με logo patch Regular Fit Denim Blue Ανοιχτό 26W 32L
#     Score: 0.565, Price: $116.45 (Save $20.55)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guess παιδικό τζιν παντελόνι πεντάτσεπο με φθαρμένη όψη και λογότυπο με στρας Denim Blue 10Y, Guess παιδικό τζιν παντελόνι πεντάτσεπο με φθαρμένη όψη και λογότυπο με στρας Denim Blue 12Y
#     Score: 0.422, Price: $101.60 (Save $25.40)
# ======================================================================
#
# --- DEMO PRODUCT 991 of 1000 ---
# 🎯 Target Item: 'L'Occitane Verbena Citrus Fresh Body Milk 250 ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Message: No suitable bundle found meeting quality thresholds for 'L'Occitane Verbena Citrus Fresh Body Milk 250 ml'. Best 2-item score: 0.27, Best 3-item score: 0.29.
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Moschino Pink Fresh Couture Bath & Shower Gel 200 ml, L'occitane Verbena Shower Gel 250 ml
#     Score: 0.424, Price: $64.85 (Save $8.43)
# ======================================================================
#
# --- DEMO PRODUCT 992 of 1000 ---
# 🎯 Target Item: 'Hermès Barénia Eau de Parfum 100ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Guess γυναικεία mini τσάντα χειρός μονόχρωμη με αποσπώμενα pouches "Latona" Μαύρο ONE SIZE
#     Score: 0.487, Price: $197.50 (Save $29.51)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: L'Occitane Shea Butter Hand Cream 150ml, L'Occitane Shea Butter Hand Cream 30 ml
#     Score: 0.404, Price: $151.66 (Save $19.71)
# ======================================================================
#
# --- DEMO PRODUCT 993 of 1000 ---
# 🎯 Target Item: 'L'Occitane Shea Foot Cream 150ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Happy Socks unisex κοντές κάλτσες σε διάφορα σχέδια (Σετ 2 τεμάχια) Μαύρο 41/46, Happy Socks unisex κάλτσες "Mushroom" Πολύχρωμο 41-46
#     Score: 0.397, Price: $40.66 (Save $8.93)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Happy Socks unisex κάλτσες "Mushroom" Πολύχρωμο 41-46, L'occitane Verbena Shower Gel 250 ml
#     Score: 0.388, Price: $46.64 (Save $7.28)
# ======================================================================
#
# --- DEMO PRODUCT 994 of 1000 ---
# 🎯 Target Item: 'Nautica ανδρική μπλούζα πόλο κοντομάνικη με monogram και 1/2 φερμουάρ Regular Fit "Patrick" Κίτρινο L'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Geox ανδρικά sneakers "Spherica" Μπεζ 40, Boboli καπέλο με σχέδιο ζωάκι Τυρκουάζ M/50
#     Score: 0.463, Price: $133.66 (Save $33.41)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Happy Socks unisex κάλτσες "Mushroom" Πολύχρωμο 41-46, Boboli καπέλο με σχέδιο ζωάκι Τυρκουάζ M/50
#     Score: 0.390, Price: $60.43 (Save $15.11)
# ======================================================================
#
# --- DEMO PRODUCT 995 of 1000 ---
# 🎯 Target Item: 'Dior Capture Day Creme Refill High-Performance Anti-Aging Correction 50 ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Message: No suitable bundle found meeting quality thresholds for 'Dior Capture Day Creme Refill High-Performance Anti-Aging Correction 50 ml'. Best 2-item score: 0.25, Best 3-item score: 0.27.
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: L'Occitane Shea Butter Hand Cream 150ml, L'Occitane Shea Butter Hand Cream 30 ml
#     Score: 0.393, Price: $110.19 (Save $17.20)
# ======================================================================
#
# --- DEMO PRODUCT 996 of 1000 ---
# 🎯 Target Item: 'Gant ανδρικό τζην παντελόνι πεντάτσεπο Regular Fit (34L) Λευκό 32'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Nautica ανδρικό T-shirt με logo print Regular Fit "Miltown" Κίτρινο L, Happy Socks unisex κάλτσες "Mushroom" Πολύχρωμο 41-46
#     Score: 0.415, Price: $104.70 (Save $26.17)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 2-Item Bundle
#     With: Nautica ανδρικό T-shirt με logo print Regular Fit "Miltown" Γκρι Γαλάζιο M
#     Score: 0.526, Price: $110.08 (Save $19.42)
# ======================================================================
#
# --- DEMO PRODUCT 997 of 1000 ---
# 🎯 Target Item: 'Dior Forever Natural Bronze Glow Sun-Kissed Finish Healthy Glow Powder 032 Pink Bronze'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 2-Item Bundle
#     With: Hair Rituel by Sisley Regenerating Hair Care Mask With Botanical Oils 200 ml
#     Score: 0.365, Price: $135.74 (Save $20.28)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 11 Le Beige Noisette - Satin, Guerlain Rouge G The Refill The Customisable Ultra-Care Lipstick 829 Le Fuchsia Profond - Satin
#     Score: 0.411, Price: $117.76 (Save $15.30)
# ======================================================================
#
# --- DEMO PRODUCT 998 of 1000 ---
# 🎯 Target Item: 'Yves Saint Laurent Libre L'Absolu Platine Yves Saint Laurent Libre L'Absolu Platine 90 ml'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Guess γυναικείο πορτοφόλι με ανάγλυφο σχέδιο και μεταλλικό λογότυπο "Laurel" Μαύρο ONE SIZE, Hair Rituel by Sisley Regenerating Hair Care Mask With Botanical Oils 200 ml
#     Score: 0.413, Price: $249.23 (Save $54.71)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Guess γυναικείο πορτοφόλι με ανάγλυφο σχέδιο και μεταλλικό λογότυπο "Laurel" Μαύρο ONE SIZE, Lancôme Lip Idôle Lip Shaper 1,2 gr Mahogany Μauve
#     Score: 0.368, Price: $178.08 (Save $39.09)
# ======================================================================
#
# --- DEMO PRODUCT 999 of 1000 ---
# 🎯 Target Item: 'Hugo Boss ανδρική γραβάτα με πουά σχέδιο Μπλε Σκούρο ONE SIZE'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Desigual γυναικείο T-shirt με floral print "Plata" Γαλάζιο M, Forel γυναικεία μπλούζα δίχρωμη Μπεζ 52
#     Score: 0.481, Price: $121.51 (Save $30.38)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 2-Item Bundle
#     With: Desigual γυναικείο T-shirt με floral print "Plata" Γαλάζιο M
#     Score: 0.566, Price: $72.66 (Save $12.82)
# ======================================================================
#
# --- DEMO PRODUCT 1000 of 1000 ---
# 🎯 Target Item: 'Camper ανδρικά δερμάτινα παπούτσια με ελαστικά κορδόνια "Peu Touring" Μαύρο 44'
# --------------------------------------------------
#   👤 For User A (44140.0):
#     Recommends: 3-Item Bundle
#     With: Gant ανδρικό καπέλο με κεντημένο graphic logo Μπλε Σκούρο ONE SIZE, Boboli καπέλο με σχέδιο ζωάκι Τυρκουάζ M/50
#     Score: 0.444, Price: $90.95 (Save $22.74)
# ------------------------------
#   👤 For User B (49464.0):
#     Recommends: 3-Item Bundle
#     With: Gant ανδρικό καπέλο με κεντημένο graphic logo Μπλε Σκούρο ONE SIZE, Boboli καπέλο με σχέδιο ζωάκι Τυρκουάζ M/50
#     Score: 0.417, Price: $90.95 (Save $22.74)
# ======================================================================
